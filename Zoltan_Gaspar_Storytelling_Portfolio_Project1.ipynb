# %% [markdown]
# <a href="https://colab.research.google.com/github/z0li627/DS-Unit-1-Build/blob/master/Zoltan_Gaspar_Storytelling_Portfolio_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/co2_conc_1850.csv')
df.describe()
# Out:
#               Year    conc_ppm
# count   169.000000  169.000000
# mean   1934.000000  317.474136
# std      48.930222   31.441900
# min    1850.000000  286.104000
# 25%    1892.000000  293.591000
# 50%    1934.000000  308.257000
# 75%    1976.000000  331.195000
# max    2018.000000  405.385000

# %%
df.head()
# Out:
#   Entity      Code  Year  conc_ppm
# 0  World  OWID_WRL  1850   287.058
# 1  World  OWID_WRL  1851   287.190
# 2  World  OWID_WRL  1852   287.263
# 3  World  OWID_WRL  1853   287.272
# 4  World  OWID_WRL  1854   287.223

# %%
df.isnull().sum().any()
# Out:
# False

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.pairplot(df)

# %%
sns.pairplot(df, x_vars='Year', y_vars='conc_ppm', height=8, aspect=2);

# %%
plt.figure(figsize=(16,8))
sns.set(style="darkgrid")
sns.lineplot(x='Year', y='conc_ppm', data=df);

# %%
df2 = pd.read_csv('/content/temp_anom_1850.csv')
df2.describe()
# Out:
#        Code         Year      Median       Upper       Lower
# count   0.0   169.000000  169.000000  169.000000  169.000000
# mean    NaN  1934.000000   -0.090615   -0.053663   -0.136095
# std     NaN    48.930222    0.301642    0.298758    0.311725
# min     NaN  1850.000000   -0.544000   -0.498000   -0.597000
# 25%     NaN  1892.000000   -0.296000   -0.258000   -0.358000
# 50%     NaN  1934.000000   -0.171000   -0.134000   -0.204000
# 75%     NaN  1976.000000    0.045000    0.067000    0.020000
# max     NaN  2018.000000    0.797000    0.835000    0.762000

# %%
df2.isnull().sum().any()
# Out:
# True

# %%
plt.figure(figsize=(16,8))
sns.set(style="darkgrid")
sns.lineplot(x='Year', y='Median', data=df2);

# %%
sns.pairplot(df2, x_vars='Year', y_vars='Median', height=8, aspect=2);

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Year', y='Median', data=df2);
