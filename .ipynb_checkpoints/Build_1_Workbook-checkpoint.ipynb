# %% [markdown]
# Is "power creep" a (numerically) observable phenomenon in the game _Magic: the Gathering_? How has power creep changed in each individual color and even Creature type over the years?
#
# https://github.com/LambdaSchool/DS-Unit-1-Build/pull/26

# %% [markdown]
# # Day 1 Work

# %%
from mtgsdk import Card
from mtgsdk import Set
from mtgsdk import Type
from mtgsdk import Supertype
from mtgsdk import Subtype
from mtgsdk import Changelog

# %%
sets = Set.all()

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cards.csv')

# %%
properties = ['code', 'release_date']

# %%
setarray = np.array([[getattr(st, prop) for prop in properties] for st in sets])

# %%
setarray = pd.DataFrame(data=setarray, columns = properties)

# %%
setarray[setarray.code == 'PUMA']
# Out:
#      code release_date
# 381  PUMA   2018-12-07

# %%
setarray.release_date = pd.to_datetime(setarray.release_date)

# %%
df = df.merge(setarray[['code', 'release_date']], how='inner', on='code')

# %%
df.name.value_counts()
# Out:
# Llanowar Elves       44
# Serra Angel          42
# Shivan Dragon        34
# Birds of Paradise    32
# Air Elemental        32
#                      ..
# Somberwald Dryad      1
# Volcano Imp           1
# Windwright Mage       1
# Reveille Squad        1
# Polis Crusher         1
# Name: name, Length: 10868, dtype: int64

# %%
df = df.sort_values(['name', 'release_date'])
df[df.code == 'UMA']
# Out:
#                     name  cmc              colors                        type  \
# 21389        Aethersnipe  6.0            ['Blue']        Creature — Elemental
# 21390    Akroan Crusader  1.0             ['Red']    Creature — Human Soldier
# 21391  Ancestor's Chosen  7.0           ['White']     Creature — Human Cleric
# 21392   Angel of Despair  7.0  ['Black', 'White']            Creature — Angel
# 21393              Anger  4.0             ['Red']      Creature — Incarnation
# ...                  ...  ...                 ...                         ...
# 21506  Wickerbough Elder  4.0           ['Green']  Creature — Treefolk Shaman
# 21507       Wild Mongrel  2.0           ['Green']            Creature — Hound
# 21508    Wingsteed Rider  3.0           ['White']     Creature — Human Knight
# 21509    Woodfall Primus  8.0           ['Green']  Creature — Treefolk Shaman
# 21510   Young Pyromancer  2.0             ['Red']     Creature — Human Shaman
#
#                      subtypes    rarity power toughness  \
# 21389           ['Elemental']    Common     4         4
# 21390    ['Human', 'Soldier']    Common     1         1
# 21391     ['Human', 'Cleric']  Uncommon     4         4
# 21392               ['Angel']  Uncommon     5         5
# 21393         ['Incarnation']  Uncommon     2         2
# ...                       ...       ...   ...       ...
# 21506  ['Treefolk', 'Shaman']    Common     4         4
# 21507               ['Hound']    Common     2         2
# 21508     ['Human', 'Knight']    Common     2         2
# 21509  ['Treefolk', 'Shaman']      Rare     6         6
# 21510     ['Human', 'Shaman']  Uncommon     2         1
#
#                                                image_url code release_date
# 21389  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21390  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21391  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21392  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21393  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# ...                                                  ...  ...          ...
# 21506  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21507  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21508  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21509  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
# 21510  http://gatherer.wizards.com/Handlers/Image.ash...  UMA   2018-12-07
#
# [122 rows x 11 columns]

# %%
non_competitive_sets_time_travelling_reprints_and_promos = ['PRM','CMB1', 'ARC', 'UNH', 'UGL', 'UST',
                                                            'C13', 'C14', 'C15', 'C16', 'C17', 'C19',
                                                            'V11', 'ANA', 'CP3', 'DDF', 'DDJ', 'DDL',
                                                            'DDN', 'DDP', 'DDQ', 'DRB', 'F03', 'F13',
                                                            'F14', 'F15', 'F17', 'GN2', 'H17', 'HHO',
                                                            'HOP', 'HTR','HTR17','HTR18','J17','MGB',
                                                            'MP2','PAL03', 'PAL04', 'PAL05', 'PAL06',
                                                            'PAVR','PBNG','PC2','PCEL','PCMP','PDGM',
                                                            'CMD', 'PDKA', 'PDP13', 'PDP14',  'PDRC',
                                                            'A25', 'CM1', 'CM2', 'E01', 'J15', 'MB1',
                                                            'OC13','OC15','OC16','OC19','OCMD','PCA',
                                                            'PG07', 'PG08', 'PGPX', 'PGTC',   'PHEL',
                                                            'PHPR', 'PISD', 'PJOU', 'PLPA',   'PM10',
                                                            'PM11', 'PM12', 'PM13', 'PM14',   'PM15',
                                                            'PMBS', 'PMEI', 'PNPH', 'PPRE',   'PPRO',
                                                            'PRED', 'PREL', 'PRES', 'PRIX',   'PRNA',
                                                            'PROE', 'PRTR', 'PS15', 'PSAL',   'PSOM',
                                                            'PSUS',  'PTG',  'PTHS',  'PURL', 'PUST',
                                                            'PWP09', 'PWP10','PWP11','PWP12', 'PWPN',
                                                            'PWWK','PZ1','PZ2','PZEN', 'UGIN', 'V15',
                                                            'VMA', 'EMA', '8ED', 'G18', 'GNT', 'IMA',
                                                            'J14', 'OC17','PCMD','PJJT', 'SLD','UMA',
                                                            'J18', 'GS1', 'PXLN', 'C18', 'CN2','CNS',
                                                            'MH1', 'PUMA']
df2 = df[df.code.isin(non_competitive_sets_time_travelling_reprints_and_promos) == False].dropna(how='any',
              subset=['power', 'toughness']).drop_duplicates(subset='name',
                                                             keep='first')
df2 = df2.reset_index().drop('index', axis=1)

# %%
df2 = df2[(df2.power == '-1') | df2.power.apply(lambda x : x.isdigit())]

# %%
df2 = df2[(df2.toughness == '-1') | df2.toughness.apply(lambda x : x.isdigit())]

# %%
df2.power = pd.to_numeric(df2.power)
df2.toughness = pd.to_numeric(df2.toughness)

# %%
df2.to_csv('final_mtg_data.csv')

# %%
df2['total_pt'] = df2.power + df2.toughness

# %%
df2
# Out:
#                       name  cmc                      colors  \
# 0           Abattoir Ghoul  4.0                   ['Black']
# 1          Abbey Gargoyles  5.0                   ['White']
# 2            Abbey Griffin  4.0                   ['White']
# 3             Abbey Matron  3.0                   ['White']
# 4      Abbot of Keral Keep  2.0                     ['Red']
# ...                    ...  ...                         ...
# 10329    Zur the Enchanter  4.0  ['Black', 'Blue', 'White']
# 10330      Zuran Enchanter  2.0                    ['Blue']
# 10331    Zuran Spellcaster  3.0                    ['Blue']
# 10332    Zurgo Bellstriker  1.0                     ['Red']
# 10333    Zurgo Helmsmasher  5.0   ['Black', 'Red', 'White']
#
#                                     type             subtypes    rarity  \
# 0                      Creature — Zombie           ['Zombie']  Uncommon
# 1                    Creature — Gargoyle         ['Gargoyle']  Uncommon
# 2                     Creature — Griffin          ['Griffin']    Common
# 3                Creature — Human Cleric  ['Human', 'Cleric']    Common
# 4                  Creature — Human Monk    ['Human', 'Monk']      Rare
# ...                                  ...                  ...       ...
# 10329  Legendary Creature — Human Wizard  ['Human', 'Wizard']      Rare
# 10330            Creature — Human Wizard  ['Human', 'Wizard']    Common
# 10331            Creature — Human Wizard  ['Human', 'Wizard']    Common
# 10332   Legendary Creature — Orc Warrior   ['Orc', 'Warrior']      Rare
# 10333   Legendary Creature — Orc Warrior   ['Orc', 'Warrior']    Mythic
#
#        power  toughness                                          image_url  \
# 0          3          2  http://gatherer.wizards.com/Handlers/Image.ash...
# 1          3          4  http://gatherer.wizards.com/Handlers/Image.ash...
# 2          2          2  http://gatherer.wizards.com/Handlers/Image.ash...
# 3          1          3  http://gatherer.wizards.com/Handlers/Image.ash...
# 4          2          1  http://gatherer.wizards.com/Handlers/Image.ash...
# ...      ...        ...                                                ...
# 10329      1          4  http://gatherer.wizards.com/Handlers/Image.ash...
# 10330      1          1  http://gatherer.wizards.com/Handlers/Image.ash...
# 10331      1          1  http://gatherer.wizards.com/Handlers/Image.ash...
# 10332      2          2  http://gatherer.wizards.com/Handlers/Image.ash...
# 10333      7          2  http://gatherer.wizards.com/Handlers/Image.ash...
#
#       code release_date  total_pt
# 0      ISD   2011-09-30         5
# 1      HML   1995-10-01         7
# 2      ISD   2011-09-30         4
# 3      HML   1995-10-01         4
# 4      ORI   2015-07-17         3
# ...    ...          ...       ...
# 10329  CSP   2006-07-21         5
# 10330  ICE   1995-06-01         2
# 10331  ICE   1995-06-01         2
# 10332  DTK   2015-03-27         4
# 10333  KTK   2014-09-26         9
#
# [10190 rows x 12 columns]

# %%
df2 = df2[['name', 'colors', 'cmc', 'total_pt', 'power',
       'toughness', 'type', 'subtypes', 'rarity', 'image_url', 'code', 'release_date']]

# %%
df2.colors = df2.colors.apply(lambda x : x.strip('][').replace("'", "").split(', '))

# %%
df2.subtypes = df2.subtypes.apply(lambda x : x.strip('][').replace("'", "").split(', '))

# %%
df2['legendary'] = df2.type.apply(lambda x : 'Legendary' in x)

# %%
df2.legendary.value_counts()
# Out:
# False    9387
# True      803
# Name: legendary, dtype: int64

# %%
df2['stat_cost_ratio'] = df2.total_pt / df2.cmc

# %%
df2 = df2[['name', 'colors', 'power',
       'toughness', 'total_pt', 'cmc', 'stat_cost_ratio', 'type', 'subtypes', 'rarity', 'image_url', 'code', 'release_date']]

# %% [markdown]
# # Day 2 Work

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
df = pd.read_csv('final_mtg_data.csv', index_col='Unnamed: 0')
df
# Out:
#                       name  cmc                      colors  \
# 0           Abattoir Ghoul  4.0                   ['Black']
# 1          Abbey Gargoyles  5.0                   ['White']
# 2            Abbey Griffin  4.0                   ['White']
# 3             Abbey Matron  3.0                   ['White']
# 4      Abbot of Keral Keep  2.0                     ['Red']
# ...                    ...  ...                         ...
# 10085    Zur the Enchanter  4.0  ['Black', 'Blue', 'White']
# 10086      Zuran Enchanter  2.0                    ['Blue']
# 10087    Zuran Spellcaster  3.0                    ['Blue']
# 10088    Zurgo Bellstriker  1.0                     ['Red']
# 10089    Zurgo Helmsmasher  5.0   ['Black', 'Red', 'White']
#
#                                     type             subtypes    rarity  \
# 0                      Creature — Zombie           ['Zombie']  Uncommon
# 1                    Creature — Gargoyle         ['Gargoyle']  Uncommon
# 2                     Creature — Griffin          ['Griffin']    Common
# 3                Creature — Human Cleric  ['Human', 'Cleric']    Common
# 4                  Creature — Human Monk    ['Human', 'Monk']      Rare
# ...                                  ...                  ...       ...
# 10085  Legendary Creature — Human Wizard  ['Human', 'Wizard']      Rare
# 10086            Creature — Human Wizard  ['Human', 'Wizard']    Common
# 10087            Creature — Human Wizard  ['Human', 'Wizard']    Common
# 10088   Legendary Creature — Orc Warrior   ['Orc', 'Warrior']      Rare
# 10089   Legendary Creature — Orc Warrior   ['Orc', 'Warrior']    Mythic
#
#        power  toughness                                          image_url  \
# 0          3          2  http://gatherer.wizards.com/Handlers/Image.ash...
# 1          3          4  http://gatherer.wizards.com/Handlers/Image.ash...
# 2          2          2  http://gatherer.wizards.com/Handlers/Image.ash...
# 3          1          3  http://gatherer.wizards.com/Handlers/Image.ash...
# 4          2          1  http://gatherer.wizards.com/Handlers/Image.ash...
# ...      ...        ...                                                ...
# 10085      1          4  http://gatherer.wizards.com/Handlers/Image.ash...
# 10086      1          1  http://gatherer.wizards.com/Handlers/Image.ash...
# 10087      1          1  http://gatherer.wizards.com/Handlers/Image.ash...
# 10088      2          2  http://gatherer.wizards.com/Handlers/Image.ash...
# 10089      7          2  http://gatherer.wizards.com/Handlers/Image.ash...
#
#       code release_date
# 0      ISD   2011-09-30
# 1      HML   1995-10-01
# 2      ISD   2011-09-30
# 3      HML   1995-10-01
# 4      ORI   2015-07-17
# ...    ...          ...
# 10085  CSP   2006-07-21
# 10086  ICE   1995-06-01
# 10087  ICE   1995-06-01
# 10088  DTK   2015-03-27
# 10089  KTK   2014-09-26
#
# [9947 rows x 11 columns]

# %%
df.release_date = pd.to_datetime(df.release_date)

# %%
df['total_pt'] = df.power + df.toughness

# %%
df.colors = df.colors.apply(lambda x : x.strip('][').replace("'", "").split(', '))

# %%
df.subtypes = df.subtypes.apply(lambda x : x.strip('][').replace("'", "").split(', '))

# %%
df['legendary'] = df.type.apply(lambda x : 'Legendary' in x)

# %%
df['stat_cost_ratio'] = df[['total_pt', 'cmc']].apply(lambda x: x[0] / x[1] if x[1] > 0 else 0, axis=1)

# %%
df = df[['name', 'colors', 'power',
       'toughness', 'total_pt', 'cmc', 'stat_cost_ratio', 'type', 'subtypes', 'rarity', 'image_url', 'code', 'release_date']]

# %%
df.stat_cost_ratio.isnull().sum()
# Out:
# 0

# %%
grouped = df.groupby('release_date')
colorf = lambda key : tuple(colors.hsv_to_rgb(((key.year - 1993) / 27, 1, 0.5)))
fig, ax = plt.subplots()
means = []
dates = []
sets =  []
for key, group in grouped:
    means += [group.stat_cost_ratio.mean()]
    dates += [key]
    sets  += [group.code.iloc[0]]
data = pd.DataFrame(data=np.array([dates, sets, means]).T,
                    columns=['date', 'set', 'mean'])
# calc the trendline
z = np.polyfit(data.date, data.mean, 1)
p = np.poly1d(z)
plt.plot(data.date,p(data.date),"r--")
data.plot(ax = ax, x='date', y='mean', label=None)
ax.get_legend().remove();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-453-abc162772333> in <module>
#      12                     columns=['date', 'set', 'mean'])
#      13 # calc the trendline
# ---> 14 z = np.polyfit(data.date, data.mean, 1)
#      15 p = np.poly1d(z)
#      16 plt.plot(data.date,p(data.date),"r--")
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     587     """
#     588     order = int(deg) + 1
# --> 589     x = NX.asarray(x) + 0.0
#     590     y = NX.asarray(y) + 0.0
#     591
#
# TypeError: ufunc add cannot use operands with types dtype('<M8[ns]') and dtype('float64')

# %%
grouped = df.groupby('release_date')
print(len(grouped))
for key, group in grouped:
    if key.year == 2004:
        print(group.code.iloc[0])
    print(key, group.stat_cost_ratio.mean())
# Out:
# 100
# 1993-08-05 00:00:00 1.4982954545454545
# 1993-12-17 00:00:00 1.7228682170542635
# 1994-03-04 00:00:00 1.2159523809523807
# 1994-06-01 00:00:00 1.2793174603174597
# 1994-08-01 00:00:00 1.3359835600907028
# 1994-11-01 00:00:00 1.4030864197530863
# 1995-06-01 00:00:00 1.330228937728938
# 1995-10-01 00:00:00 1.2951282051282054
# 1996-06-10 00:00:00 1.4067204301075271
# 1996-10-08 00:00:00 1.500190476190476
# 1997-02-03 00:00:00 1.4010763209393344
# 1997-05-01 00:00:00 1.5672473867595818
# 1997-06-09 00:00:00 1.842792792792793
# 1997-10-14 00:00:00 1.33416184041184
# 1998-03-02 00:00:00 1.3406565656565657
# 1998-06-01 00:00:00 1.4612312030075185
# 1998-06-15 00:00:00 1.2938025210084032
# 1998-10-12 00:00:00 1.647926929392447
# 1999-02-15 00:00:00 1.3363287250384022
# 1999-05-01 00:00:00 1.3137182539682541
# 1999-06-07 00:00:00 1.3047949735449733
# 1999-07-01 00:00:00 1.3947845804988663
# 1999-10-04 00:00:00 1.382190476190476
# 2000-02-14 00:00:00 1.4798280423280423
# 2000-06-05 00:00:00 1.4608268983268984
# 2000-10-02 00:00:00 1.425885630190266
# 2001-02-05 00:00:00 1.4430555555555555
# 2001-06-04 00:00:00 1.4124568668046926
# 2001-10-01 00:00:00 1.2718081435472741
# 2002-02-04 00:00:00 1.3657414182062069
# 2002-05-27 00:00:00 1.343121693121693
# 2002-10-07 00:00:00 1.3849422799422804
# 2003-02-03 00:00:00 1.3662698412698413
# 2003-05-26 00:00:00 1.3201855742296917
# 2003-10-02 00:00:00 1.2443374741200832
# DST
# 2004-02-06 00:00:00 1.1657426303854879
# 5DN
# 2004-06-04 00:00:00 1.2965091225365195
# CHK
# 2004-10-01 00:00:00 1.4049211248285318
# 2005-02-04 00:00:00 1.4807367149758461
# 2005-06-03 00:00:00 1.3917724867724868
# 2005-10-07 00:00:00 1.453601953601953
# 2006-02-03 00:00:00 1.300575173889781
# 2006-05-05 00:00:00 1.238783068783069
# 2006-07-21 00:00:00 1.7248376623376622
# 2006-10-06 00:00:00 1.35246806039489
# 2007-02-02 00:00:00 1.5242183742183741
# 2007-05-04 00:00:00 1.4516165413533832
# 2007-10-12 00:00:00 1.4767750213857995
# 2008-02-01 00:00:00 1.464468864468864
# 2008-05-02 00:00:00 1.5413118889940087
# 2008-07-25 00:00:00 1.5212178676780448
# 2008-10-03 00:00:00 1.4120410759723732
# 2009-02-06 00:00:00 1.612236987818383
# 2009-04-30 00:00:00 1.543253968253968
# 2009-07-17 00:00:00 1.5658602150537635
# 2009-10-02 00:00:00 1.502559702559702
# 2010-02-05 00:00:00 1.8449163449163448
# 2010-04-23 00:00:00 1.5651642475171892
# 2010-07-16 00:00:00 1.711443932411674
# 2010-10-01 00:00:00 1.525255102040816
# 2011-02-04 00:00:00 1.4804701627486438
# 2011-05-13 00:00:00 1.3775744047619047
# 2011-07-15 00:00:00 1.5303675856307435
# 2011-09-30 00:00:00 1.7605633802816893
# 2012-02-03 00:00:00 1.5628990057561492
# 2012-05-04 00:00:00 1.516428571428571
# 2012-07-13 00:00:00 1.5216374269005846
# 2012-10-05 00:00:00 1.614550463310793
# 2013-02-01 00:00:00 1.543198672911788
# 2013-05-03 00:00:00 1.4425309849967387
# 2013-07-19 00:00:00 1.4519626769626766
# 2013-09-27 00:00:00 1.6534391534391537
# 2014-02-07 00:00:00 1.4989813451153655
# 2014-05-02 00:00:00 1.7323366555924695
# 2014-07-18 00:00:00 1.3755437977660199
# 2014-09-26 00:00:00 1.6596418732782368
# 2015-01-23 00:00:00 1.5519379844961236
# 2015-03-27 00:00:00 1.6846500721500726
# 2015-07-17 00:00:00 1.576236263736264
# 2015-10-02 00:00:00 1.5874830810877318
# 2016-01-22 00:00:00 1.6929307805596465
# 2016-04-08 00:00:00 1.9181547619047616
# 2016-07-22 00:00:00 1.8079267432650885
# 2016-09-30 00:00:00 1.626183712121212
# 2017-01-20 00:00:00 1.5866666666666671
# 2017-04-28 00:00:00 1.8835870413739269
# 2017-06-09 00:00:00 1.4001536098310294
# 2017-07-14 00:00:00 1.6632936507936507
# 2017-09-29 00:00:00 1.6582754629629626
# 2018-01-19 00:00:00 1.6208971088435378
# 2018-04-27 00:00:00 1.6224095238095235
# 2018-06-08 00:00:00 1.390004105090312
# 2018-07-13 00:00:00 1.727791461412151
# 2018-10-05 00:00:00 1.6117346938775505
# 2019-01-25 00:00:00 1.6547273982056585
# 2019-04-10 00:00:00 1.3333333333333333
# 2019-05-03 00:00:00 1.636915887850467
# 2019-07-12 00:00:00 1.6105654761904762
# 2019-10-04 00:00:00 1.7076221397649964
# 2020-01-24 00:00:00 1.8010416666666664
