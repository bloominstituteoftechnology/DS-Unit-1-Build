# %% [markdown]
# ### Question: Should developers prioritize Play Station over Xbox

# %% [markdown]
# # Import relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Make paths for the csvs

# %%
ps4 = 'C://Users//allan//OneDrive//Desktop//data_sets//build_week_1//189386_422697_bundle_archive//PS4_GamesSales.csv'
xbox1 = 'C://Users//allan//OneDrive//Desktop//data_sets//build_week_1//189386_422697_bundle_archive//XboxOne_GameSales.csv'

# %% [markdown]
# # Read in csvs as df

# %%
ps_df = pd.read_csv(ps4, encoding="cp1252")
xbox_df = pd.read_csv(xbox1, encoding="cp1252")

# %% [markdown]
# # Inspect

# %%
ps_df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
xbox_df.head()
# Out:
#    Pos                       Game    Year             Genre  \
# 0    1         Grand Theft Auto V  2014.0            Action
# 1    2  Call of Duty: Black Ops 3  2015.0           Shooter
# 2    3         Call of Duty: WWII  2017.0           Shooter
# 3    4      Red Dead Redemption 2  2018.0  Action-Adventure
# 4    5                  MineCraft  2014.0              Misc
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# 0     Rockstar Games           4.70    3.25   0.01           0.76    8.72
# 1         Activision           4.63    2.04   0.02           0.68    7.37
# 2         Activision           3.75    1.91   0.00           0.57    6.23
# 3     Rockstar Games           3.76    1.47   0.00           0.54    5.77
# 4  Microsoft Studios           3.23    1.71   0.00           0.49    5.43

# %%
ps_df.isnull().sum()
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
xbox_df.isnull().sum()
# Out:
# Pos                0
# Game               0
# Year             108
# Genre              0
# Publisher        108
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
ps_df.shape
# Out:
# (1034, 9)

# %%
xbox_df.shape
# Out:
# (613, 10)

# %% [markdown]
# # Clean

# %%
xbox_df.drop(index=xbox_df[xbox_df['Global'] == 0.0].index.to_list(),inplace=True)

# %%
xbox_df.drop('Pos',axis=1,inplace=True)

# %%
ps_df.drop(index=ps_df[ps_df['Global'] == 0.0].index.to_list(),inplace=True)

# %%
xbox_df.head()
# Out:
#                         Game    Year             Genre          Publisher  \
# 0         Grand Theft Auto V  2014.0            Action     Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter         Activision
# 2         Call of Duty: WWII  2017.0           Shooter         Activision
# 3      Red Dead Redemption 2  2018.0  Action-Adventure     Rockstar Games
# 4                  MineCraft  2014.0              Misc  Microsoft Studios
#
#    North America  Europe  Japan  Rest of World  Global
# 0           4.70    3.25   0.01           0.76    8.72
# 1           4.63    2.04   0.02           0.68    7.37
# 2           3.75    1.91   0.00           0.57    6.23
# 3           3.76    1.47   0.00           0.54    5.77
# 4           3.23    1.71   0.00           0.49    5.43

# %%
ps_df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
print(xbox_df.shape)
print(ps_df.shape)
# Out:
# (423, 9)
# (712, 9)

# %%
xbox_df.dropna(inplace=True)
ps_df.dropna(inplace=True)

# %%
print(xbox_df.shape)
xbox_df.head()
# Out:
# (422, 9)
#                         Game    Year             Genre          Publisher  \
# 0         Grand Theft Auto V  2014.0            Action     Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter         Activision
# 2         Call of Duty: WWII  2017.0           Shooter         Activision
# 3      Red Dead Redemption 2  2018.0  Action-Adventure     Rockstar Games
# 4                  MineCraft  2014.0              Misc  Microsoft Studios
#
#    North America  Europe  Japan  Rest of World  Global
# 0           4.70    3.25   0.01           0.76    8.72
# 1           4.63    2.04   0.02           0.68    7.37
# 2           3.75    1.91   0.00           0.57    6.23
# 3           3.76    1.47   0.00           0.54    5.77
# 4           3.23    1.71   0.00           0.49    5.43

# %%
print(ps_df.shape)
ps_df.head()
# Out:
# (709, 9)
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %% [markdown]
# # Explore

# %%
x_genres = np.sort(xbox_df['Genre'].unique())
x_sales_genre = [xbox_df[xbox_df['Genre'] == i]["Global"].sum() for i in x_genres]

ps_genres = np.sort(ps_df['Genre'].unique())
ps_sales_genre = [ps_df[ps_df['Genre'] == i]["Global"].sum() for i in ps_genres]

fig, (ax1,ax2) = plt.subplots(1,2)

fig.set_size_inches(15,7)
fig.suptitle('Sales by Genre', fontsize=16, weight='bold')

ax1.bar(range(1, len(x_genres) + 1), x_sales_genre,color="#4DB455")

ax1.set_xticks(range(1, len(x_genres) + 1))
ax1.set_xticklabels(x_genres, rotation = 'vertical', fontweight='heavy',fontsize = '12')

ax1.set_yticks(range(0,141,20))

ax1.set_xlabel("Genre", weight='bold')
ax1.set_ylabel("Sales",weight='bold')
ax1.set_title("Xbox One", weight='bold')

ax2.bar(range(1, len(ps_genres) + 1), ps_sales_genre,color="#3559C2")

ax2.set_xticks(range(1, len(ps_genres) + 1))
ax2.set_xticklabels(ps_genres, rotation = 'vertical', fontweight='bold',fontsize = '12')

ax2.set_xlabel("Genre",weight='bold')
ax2.set_ylabel("Sales",weight='bold')
ax2.set_title("PS4",weight='bold')

plt.savefig('console_sales_genre.jpeg') 

plt.show()

# %%
x_years = np.sort(xbox_df['Year'].unique())
ps_years = np.sort(ps_df['Year'].unique())

x_sales_year = [xbox_df[xbox_df["Year"] == i]["Global"].sum() for i in x_years]
ps_sales_year = [ps_df[ps_df["Year"] == i]["Global"].sum() for i in ps_years]

# %%
fig, ax = plt.subplots()
plt.style.use("fivethirtyeight")
fig.suptitle('Sales by Year', fontsize=16)

ax.plot(range(1, len(x_years) + 1), x_sales_year,color="#4DB455",label='Xbox One')
ax.plot(range(1,len(ps_years) + 1),ps_sales_year, color="#3559C2", label='PS4')
ax.set_xticks(range(1,len(x_years) + 1))
ax.set_xticklabels([int(i) for i in x_years],rotation='vertical')
ax.set_xlabel("Year")
ax.set_ylabel("Sales")
ax.legend()

fig.savefig("years_sales_line.png")

plt.show()

# %%
xbox_df = xbox_df.sort_values(by='Global',ascending=False)
ps_df = ps_df.sort_values(by='Global',ascending=False)

# %%
xbox_games = xbox_df['Game'].unique()
ps_games = ps_df['Game'].unique()

mutual_games = []

for i in ps_games:
    if i in xbox_games:
        mutual_games.append(i)

x_mutual = []

for i in xbox_games:
    if i in ps_games:
        x_mutual.append(i)

# %%
ps_sales_game = [ps_df[ps_df['Game'] == game]['Global'].sum() for game in mutual_games]
xbox_sales_game = [xbox_df[xbox_df['Game'] == game]['Global'].sum() for game in mutual_games]

# %% [markdown]
# # Top Sales from xbox on both are shown

# %%
fig,ax = plt.subplots()
plt.style.use("fivethirtyeight")

fig.suptitle('Highest Grossing Xbox Titles\non both Platforms', fontsize=14)

ax.bar(range(1,31,3),xbox_sales_game[:10], color="#4DB455",label='Xbox One')
ax.bar(range(2,31,3),ps_sales_game[:10], color="#3559C2",label='PS4')
ax.set_xticks(range(2,31,3))
ax.set_xticklabels(x_mutual[:11],rotation='vertical',fontsize=10)
ax.set_xlabel("Game")
ax.set_ylabel("Sales")
ax.legend()

fig.savefig("xbox.png")
plt.show()

# %%
#xbox_sales * 1.69 would be sales if sbos had == players as ps4

# %% [markdown]
# # Here Xbox Top Sales are shown

# %%
ps_sales_game = [ps_df[ps_df['Game'] == game]['Global'].sum() for game in x_mutual]
xbox_sales_game = [xbox_df[xbox_df['Game'] == game]['Global'].sum() for game in x_mutual]

# %%
#use x_genres include party tho
tot_genre = [ps_df[ps_df['Genre'] == genre]['Global'].sum() + xbox_df[xbox_df['Genre'] == genre]['Global'].sum() for genre in x_genres]
tot_genre.append(ps_df[ps_df['Genre'] == 'Party']['Global'].sum())
fixed_genre = list(ps_genres.copy())
fixed_genre.append('Party')
del fixed_genre[7]

# %%
fig,ax = plt.subplots()

fig.suptitle('Total Game Sales by Genre', fontsize=14)
plt.style.use("fivethirtyeight")

ax.bar(range(1, len(fixed_genre) + 1),tot_genre)
ax.set_xticks(range(1, len(fixed_genre) + 1))
ax.set_xticklabels(fixed_genre, rotation='vertical')
ax.set_xlabel("Genre")
ax.set_ylabel("Sales")

plt.show()

# %% [markdown]
# # Sales by genre by region

# %%
x_na = [xbox_df[xbox_df['Genre'] == genre]['North America'].sum() for genre in x_genres]
x_eu = [xbox_df[xbox_df['Genre'] == genre]['Europe'].sum() for genre in x_genres]
x_jp = [xbox_df[xbox_df['Genre'] == genre]['Japan'].sum() for genre in x_genres]

# %%
ps_na = [ps_df[ps_df['Genre'] == genre]['North America'].sum() for genre in ps_genres]
ps_eu = [ps_df[ps_df['Genre'] == genre]['Europe'].sum() for genre in ps_genres]
ps_jp = [ps_df[ps_df['Genre'] == genre]['Japan'].sum() for genre in ps_genres]

# %%
party = ps_na[7].copy()
del ps_na[7]
tot_na = list(np.array(x_na) + np.array(ps_na))
tot_na.insert(7,party)

# %%
party = ps_eu[7].copy()
del ps_eu[7]
tot_eu = list(np.array(x_eu) + np.array(ps_eu))
tot_eu.insert(7,party)

# %%
party = ps_jp[7].copy()
del ps_jp[7]
tot_jp = list(np.array(x_jp) + np.array(ps_jp))
tot_jp.insert(7,party)

# %%
fig, (na,eu,jp) = plt.subplots(1,3)

plt.style.use("fivethirtyeight")
fig.set_size_inches(15,7)

fig.suptitle('Total Sales Across Each Region by Genre', fontsize=16,weight='bold')

na.bar(range(1,18), tot_na, color="#F8CD05")
na.set_xticks(range(1,18))
na.set_yticks(range(0,121,10))
na.set_xticklabels(ps_genres,rotation='vertical')
na.set_title("NA Sales")
na.set_xlabel("Genre")
na.set_ylabel("Sales")

eu.bar(range(1,18), tot_eu, color="#F8CD05")
eu.set_xticks(range(1,18))
eu.set_yticks(range(0,121,10))
eu.set_xticklabels(ps_genres,rotation='vertical')
eu.set_title("Europe Sales")
eu.set_xlabel("Genre")
eu.set_ylabel("Sales")

jp.bar(range(1,18), tot_jp, color="#F8CD05")
jp.set_xticks(range(1,18))
jp.set_yticks(range(0,121,10))
jp.set_xticklabels(ps_genres,rotation='vertical')
jp.set_title("Japan Sales")
jp.set_xlabel("Genre")
jp.set_ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# # Region and Time

# %%
x_na_time_sales = [xbox_df[xbox_df['Year'] == year]['North America'].sum() for year in x_years]
x_eu_time_sales = [xbox_df[xbox_df['Year'] == year]['Europe'].sum() for year in x_years]
x_jp_time_sales = [xbox_df[xbox_df['Year'] == year]['Japan'].sum() for year in x_years]

p_na_time_sales = [ps_df[ps_df['Year'] == year]['North America'].sum() for year in ps_years]
p_eu_time_sales = [ps_df[ps_df['Year'] == year]['Europe'].sum() for year in ps_years]
p_jp_time_sales = [ps_df[ps_df['Year'] == year]['Japan'].sum() for year in ps_years]

tot_na_time_sales = np.array(x_na_time_sales) + np.array(p_na_time_sales)
tot_eu_time_sales = np.array(x_eu_time_sales) + np.array(p_eu_time_sales)
tot_jp_time_sales = np.array(x_jp_time_sales) + np.array(p_jp_time_sales)

# %%
fig, (na,eu,jp) = plt.subplots(1,3)

fig.set_size_inches(15,7)
fig.suptitle('Sales Across Each Region by Year', fontsize=16)

na.bar(range(1,7), tot_na_time_sales, color="#F8CD05")
na.set_xticks(range(1,7))
na.set_xticklabels([int(i) for i in ps_years],rotation='vertical')
na.set_yticks(range(0,101,10))
na.set_title("NA")
na.set_xlabel("Year")
na.set_ylabel("Sales")

eu.bar(range(1,7), tot_eu_time_sales, color="#F8CD05")
eu.set_xticks(range(1,7))
eu.set_xticklabels([int(i) for i in ps_years],rotation='vertical')
eu.set_yticks(range(0,101,10))
eu.set_title("Europe")
eu.set_xlabel("Year")
eu.set_ylabel("Sales")

jp.bar(range(1,7), tot_jp_time_sales, color="#F8CD05")
jp.set_xticks(range(1,7))
jp.set_xticklabels([int(i) for i in ps_years],rotation='vertical')
jp.set_yticks(range(0,101,10))
jp.set_title("Japan")
jp.set_xlabel("Year")
jp.set_ylabel("Sales")

plt.show()

# %% [markdown]
# # Scatter Genre

# %%
GENRES = ps_df['Genre'].unique()
new_map = {}
for i, j in enumerate(GENRES):
    new_map[j] = i

# %%
def remap(cell):
    return new_map[cell]

ps_df['remapped'] = ps_df['Genre'].apply(remap)
ps_df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global  remapped
# 0           6.06    9.71   0.60           3.02   19.39         0
# 1           6.18    6.05   0.41           2.44   15.09         1
# 2           5.26    6.21   0.21           2.26   13.94         2
# 3           4.67    6.21   0.40           2.12   13.40         1
# 4           1.27    8.64   0.15           1.73   11.80         3

# %%
fig, ax = plt.subplots()

ax.scatter(ps_df['remapped'],ps_df['Global'])
ax.set_xticks(range(len(GENRES) + 1))
ax.set_xticklabels(GENRES, rotation='vertical')

plt.show()

# %%
mean_sales_genre = [ps_df[ps_df['Genre'] == genre]['Global'].mean() for genre in GENRES]
fig,ax = plt.subplots()

ax.bar(range(1, len(GENRES) + 1), mean_sales_genre)
ax.set_xticks(range(1, len(GENRES) + 1))
ax.set_xticklabels(GENRES, rotation='vertical')

plt.show()

# %%
ps = [ps_df[ps_df['Game'] == game]['Global'].sum() for game in mutual_games]
xbox = [xbox_df[xbox_df['Game'] == game]['Global'].sum() for game in mutual_games]

fig,ax = plt.subplots()

ax.scatter(ps, xbox)

plt.show()

# %%
xbox_df['Global'].sum()*1.6
# Out:
# 430.14400000000006

# %%
ps_df['Global'].sum()
# Out:
# 595.4200000000001

# %%
np.array(tot_na).sum()/579
# Out:
# 0.6463730569948185

# %%
np.array(tot_eu).sum()/741
# Out:
# 0.45645074224021587

# %% [markdown]
# # Other graphs I made

# %% [markdown]
# # Genre and Time

# %%
for genre in ps_genres:
    genre_year_sales = []
    for year in ps_years:
        temp = ps_df[(ps_df['Genre'] == genre) & (ps_df['Year'] == year)]
        genre_year_sales.append(temp['Global'].sum())

    fig, ax = plt.subplots()

    fig.suptitle(f'Sales for {genre} Games by Year', fontsize=16)

    ax.bar(range(1,7), genre_year_sales, color="#F8CD05")
    ax.set_xticks(range(1,7))
    ax.set_yticks(range(0,41,10))
    ax.set_xticklabels(ps_years)
    ax.set_xlabel("Year")
    ax.set_ylabel("Sales")

    plt.show()

# %%
'''fig, (ax1,ax2) = plt.subplots(1,2)

fig.set_size_inches(15,7)
fig.suptitle('Sales by Year', fontsize=16, weight='bold')

ax1.bar(range(1, len(x_years) + 1), x_sales_year,color="#4DB455")

ax1.set_xticks(range(1,len(x_years) + 1))
ax1.set_xticklabels(x_years,rotation='vertical',weight='bold')
ax1.set_yticks(range(0,141,20))

ax1.set_xlabel("Year",weight='bold')
ax1.set_ylabel("Sales",weight='bold')

ax1.set_title("Xbox One",weight='bold')

ax2.bar(range(1,len(ps_years) + 1),ps_sales_year, color="#3559C2")

ax2.set_xticks(range(1,len(ps_years) + 1))
ax2.set_xticklabels(ps_years,rotation='vertical',weight='bold')

ax2.set_xlabel("Year",weight='bold')
ax2.set_ylabel("Sales",weight='bold')

ax2.set_title("PS4",weight='bold')

plt.savefig('console_sales_year.jpeg')

plt.show()'''
# Out:
# 'fig, (ax1,ax2) = plt.subplots(1,2)\n\nfig.set_size_inches(15,7)\nfig.suptitle(\'Sales by Year\', fontsize=16, weight=\'bold\')\n\nax1.bar(range(1, len(x_years) + 1), x_sales_year,color="#4DB455")\n\nax1.set_xticks(range(1,len(x_years) + 1))\nax1.set_xticklabels(x_years,rotation=\'vertical\',weight=\'bold\')\nax1.set_yticks(range(0,141,20))\n\nax1.set_xlabel("Year",weight=\'bold\')\nax1.set_ylabel("Sales",weight=\'bold\')\n\nax1.set_title("Xbox One",weight=\'bold\')\n\nax2.bar(range(1,len(ps_years) + 1),ps_sales_year, color="#3559C2")\n\nax2.set_xticks(range(1,len(ps_years) + 1))\nax2.set_xticklabels(ps_years,rotation=\'vertical\',weight=\'bold\')\n\nax2.set_xlabel("Year",weight=\'bold\')\nax2.set_ylabel("Sales",weight=\'bold\')\n\nax2.set_title("PS4",weight=\'bold\')\n\nplt.savefig(\'console_sales_year.jpeg\')\n\nplt.show()'

# %%
'''fig,ax = plt.subplots()
plt.style.use("fivethirtyeight")

fig.suptitle('Top Genres by Sales', fontsize=14)

ax.bar(range(1,31,3),xbox_sales_game[:10], color="#4DB455",label='Xbox One')
ax.bar(range(2,31,3),ps_sales_game[:10], color="#3559C2",label='PS4')
ax.set_xticks(range(2,31,3))
ax.set_xticklabels(x_mutual[:11],rotation='vertical',fontsize=10)
ax.set_xlabel("Game")
ax.set_ylabel("Sales")
ax.legend()

fig.savefig("total.png")
plt.show()'''
# Out:
# 'fig,ax = plt.subplots()\nplt.style.use("fivethirtyeight")\n\nfig.suptitle(\'Top Genres by Sales\', fontsize=14)\n\nax.bar(range(1,31,3),xbox_sales_game[:10], color="#4DB455",label=\'Xbox One\')\nax.bar(range(2,31,3),ps_sales_game[:10], color="#3559C2",label=\'PS4\')\nax.set_xticks(range(2,31,3))\nax.set_xticklabels(x_mutual[:11],rotation=\'vertical\',fontsize=10)\nax.set_xlabel("Game")\nax.set_ylabel("Sales")\nax.legend()\n\nfig.savefig("total.png")\nplt.show()'

# %%
'''fig, (ax1, ax2) = plt.subplots(1,2)

fig.set_size_inches(20,10)

ax1.bar(range(1, 11), xbox_sales_game[:10], color="#4DB455")

ax1.set_xticks(range(1, 11))
ax1.set_xticklabels(mutual_games[:11],rotation='vertical')
ax1.set_yticks(np.arange(0,21,2.5))

ax2.bar(range(1, 11), ps_sales_game[:10], color="#3559C2")

ax2.set_xticks(range(1, 11))
ax2.set_xticklabels(mutual_games[:11],rotation='vertical')

plt.show()'''
# Out:
# 'fig, (ax1, ax2) = plt.subplots(1,2)\n\nfig.set_size_inches(20,10)\n\nax1.bar(range(1, 11), xbox_sales_game[:10], color="#4DB455")\n\nax1.set_xticks(range(1, 11))\nax1.set_xticklabels(mutual_games[:11],rotation=\'vertical\')\nax1.set_yticks(np.arange(0,21,2.5))\n\nax2.bar(range(1, 11), ps_sales_game[:10], color="#3559C2")\n\nax2.set_xticks(range(1, 11))\nax2.set_xticklabels(mutual_games[:11],rotation=\'vertical\')\n\nplt.show()'

# %%
'''fig, (ax1, ax2) = plt.subplots(1,2)

fig.set_size_inches(20,10)
fig.suptitle('Highest Grossing Xbox Titles on both Platforms', fontsize=16, weight='bold')

ax1.bar(range(1, 11), xbox_sales_game[:10], color="#4DB455")

ax1.set_xticks(range(1, 11))
ax1.set_xticklabels(x_mutual[:11],rotation='vertical',weight='bold')
ax1.set_yticks(np.arange(0,21,2.5))
ax1.set_xlabel("Games",weight='bold')
ax1.set_ylabel("Sales",weight='bold')
ax1.set_title("Xbox One",weight='bold')

ax2.bar(range(1, 11), ps_sales_game[:10], color="#3559C2")

ax2.set_xticks(range(1, 11))
ax2.set_xticklabels(x_mutual[:11],rotation='vertical',weight='bold')
ax2.set_xlabel("Games",weight='bold')
ax2.set_ylabel("Sales",weight='bold')
ax2.set_title("PS4",weight='bold')

plt.savefig('xbox_gross.jpeg')

plt.show()'''
# Out:
# 'fig, (ax1, ax2) = plt.subplots(1,2)\n\nfig.set_size_inches(20,10)\nfig.suptitle(\'Highest Grossing Xbox Titles on both Platforms\', fontsize=16, weight=\'bold\')\n\nax1.bar(range(1, 11), xbox_sales_game[:10], color="#4DB455")\n\nax1.set_xticks(range(1, 11))\nax1.set_xticklabels(x_mutual[:11],rotation=\'vertical\',weight=\'bold\')\nax1.set_yticks(np.arange(0,21,2.5))\nax1.set_xlabel("Games",weight=\'bold\')\nax1.set_ylabel("Sales",weight=\'bold\')\nax1.set_title("Xbox One",weight=\'bold\')\n\nax2.bar(range(1, 11), ps_sales_game[:10], color="#3559C2")\n\nax2.set_xticks(range(1, 11))\nax2.set_xticklabels(x_mutual[:11],rotation=\'vertical\',weight=\'bold\')\nax2.set_xlabel("Games",weight=\'bold\')\nax2.set_ylabel("Sales",weight=\'bold\')\nax2.set_title("PS4",weight=\'bold\')\n\nplt.savefig(\'xbox_gross.jpeg\')\n\nplt.show()'

# %%
'''fig, (na,eu,jp) = plt.subplots(1,3)

fig.set_size_inches(15,7)

fig.suptitle('Xbox One Game Sales by Genre', fontsize=16)

na.bar(range(1,17), x_na, color="#4DB455")
na.set_xticks(range(1,17))
na.set_xticklabels(x_genres,rotation='vertical')
na.set_title("NA Sales")
na.set_xlabel("Genre")
na.set_ylabel("Sales")

eu.bar(range(1,17), x_eu, color="#4DB455")
eu.set_xticks(range(1,17))
eu.set_yticks(range(0,61,10))
eu.set_xticklabels(x_genres,rotation='vertical')
eu.set_title("Europe Sales")
eu.set_xlabel("Genre")
eu.set_ylabel("Sales")

jp.bar(range(1,17), x_jp, color="#4DB455")
jp.set_xticks(range(1,17))
jp.set_yticks(range(0,61,10))
jp.set_xticklabels(x_genres,rotation='vertical')
jp.set_title("Japan Sales")
jp.set_xlabel("Genre")
jp.set_ylabel("Sales")

plt.show()'''
# Out:
# 'fig, (na,eu,jp) = plt.subplots(1,3)\n\nfig.set_size_inches(15,7)\n\nfig.suptitle(\'Xbox One Game Sales by Genre\', fontsize=16)\n\nna.bar(range(1,17), x_na, color="#4DB455")\nna.set_xticks(range(1,17))\nna.set_xticklabels(x_genres,rotation=\'vertical\')\nna.set_title("NA Sales")\nna.set_xlabel("Genre")\nna.set_ylabel("Sales")\n\neu.bar(range(1,17), x_eu, color="#4DB455")\neu.set_xticks(range(1,17))\neu.set_yticks(range(0,61,10))\neu.set_xticklabels(x_genres,rotation=\'vertical\')\neu.set_title("Europe Sales")\neu.set_xlabel("Genre")\neu.set_ylabel("Sales")\n\njp.bar(range(1,17), x_jp, color="#4DB455")\njp.set_xticks(range(1,17))\njp.set_yticks(range(0,61,10))\njp.set_xticklabels(x_genres,rotation=\'vertical\')\njp.set_title("Japan Sales")\njp.set_xlabel("Genre")\njp.set_ylabel("Sales")\n\nplt.show()'

# %%
'''fig, (na,eu,jp) = plt.subplots(1,3)

fig.set_size_inches(15,7)

fig.suptitle('PS4 Sales by Genre', fontsize=16)

na.bar(range(1,18), ps_na, color="#3559C2")
na.set_xticks(range(1,18))
na.set_yticks(range(0,61,10))
na.set_xticklabels(ps_genres,rotation='vertical')
na.set_title("NA Sales")
na.set_xlabel("Genre")
na.set_ylabel("Sales")

eu.bar(range(1,18), ps_eu, color="#3559C2")
eu.set_xticks(range(1,18))
eu.set_yticks(range(0,61,10))
eu.set_xticklabels(ps_genres,rotation='vertical')
eu.set_title("Europe Sales")
eu.set_xlabel("Genre")
eu.set_ylabel("Sales")

jp.bar(range(1,18), ps_jp, color="#3559C2")
jp.set_xticks(range(1,18))
jp.set_yticks(range(0,61,10))
jp.set_xticklabels(ps_genres,rotation='vertical')
jp.set_title("Japan Sales")
jp.set_xlabel("Genre")
jp.set_ylabel("Sales")

plt.show()'''
# Out:
# 'fig, (na,eu,jp) = plt.subplots(1,3)\n\nfig.set_size_inches(15,7)\n\nfig.suptitle(\'PS4 Sales by Genre\', fontsize=16)\n\nna.bar(range(1,18), ps_na, color="#3559C2")\nna.set_xticks(range(1,18))\nna.set_yticks(range(0,61,10))\nna.set_xticklabels(ps_genres,rotation=\'vertical\')\nna.set_title("NA Sales")\nna.set_xlabel("Genre")\nna.set_ylabel("Sales")\n\neu.bar(range(1,18), ps_eu, color="#3559C2")\neu.set_xticks(range(1,18))\neu.set_yticks(range(0,61,10))\neu.set_xticklabels(ps_genres,rotation=\'vertical\')\neu.set_title("Europe Sales")\neu.set_xlabel("Genre")\neu.set_ylabel("Sales")\n\njp.bar(range(1,18), ps_jp, color="#3559C2")\njp.set_xticks(range(1,18))\njp.set_yticks(range(0,61,10))\njp.set_xticklabels(ps_genres,rotation=\'vertical\')\njp.set_title("Japan Sales")\njp.set_xlabel("Genre")\njp.set_ylabel("Sales")\n\nplt.show()'

# %%
'''fig, (na,eu,jp) = plt.subplots(1,3)

fig.set_size_inches(15,7)
fig.suptitle('Xbox One Sales Across Each Region by Year', fontsize=16)

na.bar(range(1,7), x_na_time_sales, color="#4DB455")
na.set_xticks(range(1,7))
na.set_xticklabels(x_years,rotation='vertical')
na.set_yticks(range(0,46,5))
na.set_title("NA")
na.set_xlabel("Year")
na.set_ylabel("Sales")

eu.bar(range(1,7), x_eu_time_sales, color="#4DB455")
eu.set_xticks(range(1,7))
eu.set_xticklabels(x_years,rotation='vertical')
eu.set_yticks(range(0,46,5))
eu.set_title("Europe")
eu.set_xlabel("Year")
eu.set_ylabel("Sales")

jp.bar(range(1,7), x_jp_time_sales, color="#4DB455")
jp.set_xticks(range(1,7))
jp.set_xticklabels(x_years,rotation='vertical')
jp.set_yticks(range(0,45,5))
jp.set_title("Japan")
jp.set_xlabel("Year")
jp.set_ylabel("Sales")

plt.show()'''
# Out:
# 'fig, (na,eu,jp) = plt.subplots(1,3)\n\nfig.set_size_inches(15,7)\nfig.suptitle(\'Xbox One Sales Across Each Region by Year\', fontsize=16)\n\nna.bar(range(1,7), x_na_time_sales, color="#4DB455")\nna.set_xticks(range(1,7))\nna.set_xticklabels(x_years,rotation=\'vertical\')\nna.set_yticks(range(0,46,5))\nna.set_title("NA")\nna.set_xlabel("Year")\nna.set_ylabel("Sales")\n\neu.bar(range(1,7), x_eu_time_sales, color="#4DB455")\neu.set_xticks(range(1,7))\neu.set_xticklabels(x_years,rotation=\'vertical\')\neu.set_yticks(range(0,46,5))\neu.set_title("Europe")\neu.set_xlabel("Year")\neu.set_ylabel("Sales")\n\njp.bar(range(1,7), x_jp_time_sales, color="#4DB455")\njp.set_xticks(range(1,7))\njp.set_xticklabels(x_years,rotation=\'vertical\')\njp.set_yticks(range(0,45,5))\njp.set_title("Japan")\njp.set_xlabel("Year")\njp.set_ylabel("Sales")\n\nplt.show()'

# %%
'''fig, (na,eu,jp) = plt.subplots(1,3)

fig.set_size_inches(15,7)
fig.suptitle('PS4 Sales Across Each Region by Year', fontsize=16)

na.bar(range(1,7), p_na_time_sales, color="#3559C2")
na.set_xticks(range(1,7))
na.set_xticklabels(ps_years,rotation='vertical')
na.set_yticks(range(0,61,10))
na.set_title("NA")
na.set_xlabel("Year")
na.set_ylabel("Sales")

eu.bar(range(1,7), p_eu_time_sales, color="#3559C2")
eu.set_xticks(range(1,7))
eu.set_xticklabels(ps_years,rotation='vertical')
eu.set_yticks(range(0,61,10))
eu.set_title("Europe")
eu.set_xlabel("Year")
eu.set_ylabel("Sales")

jp.bar(range(1,7), p_jp_time_sales, color="#3559C2")
jp.set_xticks(range(1,7))
jp.set_xticklabels(ps_years,rotation='vertical')
jp.set_yticks(range(0,61,10))
jp.set_title("Japan")
jp.set_xlabel("Year")
jp.set_ylabel("Sales")

plt.show()'''
# Out:
# 'fig, (na,eu,jp) = plt.subplots(1,3)\n\nfig.set_size_inches(15,7)\nfig.suptitle(\'PS4 Sales Across Each Region by Year\', fontsize=16)\n\nna.bar(range(1,7), p_na_time_sales, color="#3559C2")\nna.set_xticks(range(1,7))\nna.set_xticklabels(ps_years,rotation=\'vertical\')\nna.set_yticks(range(0,61,10))\nna.set_title("NA")\nna.set_xlabel("Year")\nna.set_ylabel("Sales")\n\neu.bar(range(1,7), p_eu_time_sales, color="#3559C2")\neu.set_xticks(range(1,7))\neu.set_xticklabels(ps_years,rotation=\'vertical\')\neu.set_yticks(range(0,61,10))\neu.set_title("Europe")\neu.set_xlabel("Year")\neu.set_ylabel("Sales")\n\njp.bar(range(1,7), p_jp_time_sales, color="#3559C2")\njp.set_xticks(range(1,7))\njp.set_xticklabels(ps_years,rotation=\'vertical\')\njp.set_yticks(range(0,61,10))\njp.set_title("Japan")\njp.set_xlabel("Year")\njp.set_ylabel("Sales")\n\nplt.show()'
